# %%
import yfinance as yf

import pandas as pd
import plotly.express as px
import datetime

liste = ["AMZN", "GOOGL", "MSFT", "AAPL"]
dico_df = {}
for i,m in enumerate(liste):
    msft = yf.Ticker(m)
    if i == 0:
        df = msft.history(period="max")[["Close"]]
        df.rename(columns={"Close":m}, inplace=True)
    else:
        temp = msft.history(period="max")[["Close"]]
        temp.rename(columns={"Close":m}, inplace=True)
        df = df.merge(temp, left_index=True, right_index=True, how="left")

    #dico_df[m]= msft.history(period="max")[["Close"]]
    #dico_df[m].rename(columns={"Close":m}, inplace=True)

# %%
df.index
# Out:
# DatetimeIndex(['1997-05-15', '1997-05-16', '1997-05-19', '1997-05-20',
#                '1997-05-21', '1997-05-22', '1997-05-23', '1997-05-27',
#                '1997-05-28', '1997-05-29',
#                ...
#                '2020-09-24', '2020-09-25', '2020-09-28', '2020-09-29',
#                '2020-09-30', '2020-10-01', '2020-10-02', '2020-10-05',
#                '2020-10-06', '2020-10-07'],
#               dtype='datetime64[ns]', name='Date', length=5889, freq=None)

# %%
url = "https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed-symbols_csv/data/595a1f263719c09a8a0b4a64f17112c6/nasdaq-listed-symbols_csv.csv"
listing = pd.read_csv(url)
listing.rename(columns={"Symbol": "value",
                        "Company Name": "label"}, inplace=True)

# %%
df.Date.dt.year.unique()
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020], dtype=int64)

# %%
df.columns
# Out:
# Index(['AMZN', 'GOOGL', 'MSFT', 'AAPL', 'Date'], dtype='object')

# %%
df['Date'] = df.index
df.Date = pd.to_datetime(df.Date)
df2 = df.melt(id_vars=["Date"])
df2.rename(columns={"value":"Close","variable":"Company"}, inplace=True)
df3=df2[df2.Date>pd.to_datetime("2019-01-01")]
fig = px.line(df3, x="Date", y="Close", color="Company")
fig.show()

# %%
stock.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1998-06-02        0.0           2.0
# 1999-01-05        0.0           3.0
# 1999-09-02        0.0           2.0

# %%
stock.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
stock.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
stock.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
